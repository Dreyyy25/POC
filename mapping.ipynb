# %%
# !pip install pydantic pydantic-ai python-dotenv ipython devtools
# Out:
# Requirement already satisfied: pydantic in c:\users\almos\anaconda3\envs\poc\lib\site-packages (2.10.3)
# Requirement already satisfied: pydantic-ai in c:\users\almos\anaconda3\envs\poc\lib\site-packages (0.0.33)
# Requirement already satisfied: python-dotenv in c:\users\almos\anaconda3\envs\poc\lib\site-packages (1.0.1)
# Requirement already satisfied: ipython in c:\users\almos\anaconda3\envs\poc\lib\site-packages (8.30.0)
# Requirement already satisfied: devtools in c:\users\almos\anaconda3\envs\poc\lib\site-packages (0.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from pydantic) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from pydantic) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from pydantic) (4.12.2)
# Requirement already satisfied: pydantic-ai-slim==0.0.33 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (0.0.33)
# Requirement already satisfied: eval-type-backport>=0.2.0 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from pydantic-ai-slim==0.0.33->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (0.2.2)
# Requirement already satisfied: griffe>=1.3.2 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from pydantic-ai-slim==0.0.33->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (1.6.0)
# Requirement already satisfied: httpx>=0.27 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from pydantic-ai-slim==0.0.33->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (0.28.1)
# Requirement already satisfied: opentelemetry-api>=1.28.0 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from pydantic-ai-slim==0.0.33->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (1.30.0)
# Requirement already satisfied: pydantic-graph==0.0.33 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from pydantic-ai-slim==0.0.33->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (0.0.33)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from pydantic-ai-slim==0.0.33->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (0.4.0)
# Requirement already satisfied: anthropic>=0.49.0 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (0.49.0)
# Requirement already satisfied: cohere>=5.13.11 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (5.14.0)
# Requirement already satisfied: groq>=0.12.0 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (0.18.0)
# Requirement already satisfied: mistralai>=1.2.5 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (1.5.0)
# Requirement already satisfied: openai>=1.65.1 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (1.65.3)
# Requirement already satisfied: google-auth>=2.36.0 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (2.38.0)
# Requirement already satisfied: requests>=2.32.3 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (2.32.3)
# Requirement already satisfied: logfire-api>=1.2.0 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from pydantic-graph==0.0.33->pydantic-ai-slim==0.0.33->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (3.7.0)
# Requirement already satisfied: decorator in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from ipython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from ipython) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from ipython) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from ipython) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from ipython) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from ipython) (5.14.3)
# Requirement already satisfied: colorama in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: asttokens<3.0.0,>=2.0.0 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from devtools) (2.0.5)
# Requirement already satisfied: executing>=1.1.1 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from devtools) (2.2.0)
# Requirement already satisfied: six in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from asttokens<3.0.0,>=2.0.0->devtools) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from jedi>=0.16->ipython) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython) (0.2.5)
# Requirement already satisfied: pure-eval in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from stack-data->ipython) (0.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from anthropic>=0.49.0->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from anthropic>=0.49.0->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from anthropic>=0.49.0->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (0.8.2)
# Requirement already satisfied: sniffio in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from anthropic>=0.49.0->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (1.3.1)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from cohere>=5.13.11->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (1.10.0)
# Requirement already satisfied: httpx-sse==0.4.0 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from cohere>=5.13.11->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (0.4.0)
# Requirement already satisfied: tokenizers<1,>=0.15 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from cohere>=5.13.11->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (0.21.0)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from cohere>=5.13.11->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (2.32.0.20250301)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from google-auth>=2.36.0->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from google-auth>=2.36.0->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from google-auth>=2.36.0->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (4.9)
# Requirement already satisfied: certifi in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from httpx>=0.27->pydantic-ai-slim==0.0.33->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from httpx>=0.27->pydantic-ai-slim==0.0.33->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (1.0.7)
# Requirement already satisfied: idna in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from httpx>=0.27->pydantic-ai-slim==0.0.33->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from httpcore==1.*->httpx>=0.27->pydantic-ai-slim==0.0.33->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (0.14.0)
# Requirement already satisfied: jsonpath-python>=1.0.6 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from mistralai>=1.2.5->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (1.0.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from mistralai>=1.2.5->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (2.9.0.post0)
# Requirement already satisfied: typing-inspect>=0.9.0 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from mistralai>=1.2.5->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (0.9.0)
# Requirement already satisfied: tqdm>4 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from openai>=1.65.1->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (4.67.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from opentelemetry-api>=1.28.0->pydantic-ai-slim==0.0.33->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (1.2.18)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from opentelemetry-api>=1.28.0->pydantic-ai-slim==0.0.33->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (8.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from requests>=2.32.3->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from requests>=2.32.3->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (2.3.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.28.0->pydantic-ai-slim==0.0.33->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (1.17.2)
# Requirement already satisfied: zipp>=3.20 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.28.0->pydantic-ai-slim==0.0.33->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (3.21.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.36.0->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (0.6.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from tokenizers<1,>=0.15->cohere>=5.13.11->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (0.29.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from typing-inspect>=0.9.0->mistralai>=1.2.5->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (1.0.0)
# Requirement already satisfied: filelock in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere>=5.13.11->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere>=5.13.11->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (2025.2.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere>=5.13.11->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\almos\anaconda3\envs\poc\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere>=5.13.11->pydantic-ai-slim[anthropic,cohere,groq,mistral,openai,vertexai]==0.0.33->pydantic-ai) (6.0.2)

# %%
import os
from dotenv import load_dotenv
from IPython.display import display, Markdown

# Load environment variables from .env file
load_dotenv()

# Get API keys from environment variables
openai_api_key = os.environ.get("OPENAI_API_KEY", "")
google_api_key = os.environ.get("GEMINI_API_KEY", "")

# Set API keys only if they're not already set
if not os.environ.get("OPENAI_API_KEY") and openai_api_key:
    os.environ["OPENAI_API_KEY"] = openai_api_key
if not os.environ.get("GEMINI_API_KEY") and google_api_key:
    os.environ["GEMINI_API_KEY"] = google_api_key

# Add error handling for missing API keys
# Check which API keys are missing and provide specific warnings
missing_keys = []
if not os.environ.get("OPENAI_API_KEY"):
    missing_keys.append("OPENAI_API_KEY")
if not os.environ.get("GEMINI_API_KEY"):
    missing_keys.append("GEMINI_API_KEY")

if missing_keys:
    print(f"Warning: The following API key(s) are missing: {', '.join(missing_keys)}")
    print(f"Some functionality using {', '.join(missing_keys)} may be limited.")
# Display a message indicating that the API keys have been loaded
display(Markdown("### API keys have been loaded successfully."))

USE_GEMINI= True
# Out:
# Warning: The following API key(s) are missing: OPENAI_API_KEY
# Some functionality using OPENAI_API_KEY may be limited.
# ### API keys have been loaded successfully.

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
from pydantic import BaseModel, Field
from typing import Optional
from devtools import debug
from dataclasses import dataclass


class YearlyValue(BaseModel):
    """Model for values that can have current and previous year figures"""
    CFY: float
    PFY: Optional[float] = None


class StatementOfProfitOrLoss(BaseModel):
    """Financial statement model for profit or loss statement with current and previous year values"""
    
    # Fields with financial definitions and common terms
    revenue: YearlyValue = Field(..., description="The income generated from normal business operations. Common terms: Revenue, Turnover, Sales, Revenue from contracts with customers")
    
    other_income: Optional[YearlyValue] = Field(None, description="Income from activities unrelated to main business operations, such as interest, dividends, or rental income. Common terms: Other income, Other operating income, Other revenue")
    
    employee_benefits_expense: Optional[YearlyValue] = Field(None, description="All costs related to employee compensation, including salaries, wages, bonuses, CPF contributions, and employee benefits. Common terms: Employee benefits expense, Staff costs, Personnel expenses, Employee costs, Salaries and wages")
    
    depreciation_expense: Optional[YearlyValue] = Field(None, description="The systematic allocation of tangible asset costs over their useful lives. Common terms: Depreciation expense, Depreciation, Depreciation of property, plant and equipment")
    
    amortisation_expense: Optional[YearlyValue] = Field(None, description="The systematic allocation of intangible asset costs over their useful lives. Common terms: Amortisation expense, Amortization expense, Amortisation, Amortization, Amortisation of intangible assets")
    
    repairs_maintenance_expense: Optional[YearlyValue] = Field(None, description="Costs incurred to maintain or repair property, equipment, and other assets. Common terms: Repairs and maintenance, Repairs and maintenance expense, Maintenance costs, Repairs expense")
    
    sales_marketing_expense: Optional[YearlyValue] = Field(None, description="Expenses related to promoting and selling products/services, including advertising, marketing campaigns, and sales staff costs. Common terms: Sales and marketing expense, Marketing expenses, Selling expenses, Marketing and distribution expenses")
    
    other_expenses: Optional[YearlyValue] = Field(None, description="Operating expenses not classified in other specific categories, often including administrative, utility, and general business costs. Common terms: Other expenses, Other operating expenses, General expenses, Administrative expenses")
    
    other_gains_losses: Optional[YearlyValue] = Field(None, description="Gains or losses from non-operating activities or one-time events, including foreign exchange differences or asset disposals. Common terms: Other gains and losses, Foreign exchange gain/(loss), Fair value changes, Forex gain/loss")
    
    finance_costs_net: Optional[YearlyValue] = Field(None, description="The net cost of financing, typically interest expense minus interest income, including loan interest, bond interest, and other financing costs. Common terms: Finance costs, Finance income, Finance expense, Interest expense, Interest income, Net finance costs")
    
    share_of_profit_loss_associates: Optional[YearlyValue] = Field(None, description="The entity's share of profits or losses from investments in associates and joint ventures accounted for using the equity method. Common terms: Share of profit of associates, Share of results of associates, Share of profit (loss) of associates and joint ventures")
    
    profit_loss_before_taxation: YearlyValue = Field(..., description="The profit or loss before income tax expense is considered, representing operational performance before tax obligations. Common terms: Profit before tax, Profit before taxation, Earnings before tax, Profit before income tax")
    
    income_tax_expense_benefit: YearlyValue = Field(..., description="The amount of income taxes payable or recoverable for the period, including current and deferred tax. Common terms: Income tax expense, Tax expense, Taxation, Income tax benefit, Tax benefit")
    
    profit_loss_discontinued_operations: Optional[YearlyValue] = Field(None, description="The profit or loss from business components that have been disposed of or classified as held for sale, shown net of tax. Common terms: Profit from discontinued operations, Loss from discontinued operations, Discontinued operations")
    
    total_profit_loss: Optional[YearlyValue] = Field(None, description="The bottom-line profit or loss for the financial period after all expenses, including tax. Common terms: Profit for the year, Loss for the year, Net profit, Net loss, Profit for the period, Total comprehensive income")
    
    profit_loss_attributable_to_owners: Optional[YearlyValue] = Field(None, description="The portion of total profit or loss that belongs to the shareholders or owners of the parent company. Common terms: Profit attributable to owners, Profit attributable to shareholders, Profit attributable to equity holders")
    
    profit_loss_attributable_to_non_controlling: Optional[YearlyValue] = Field(None, description="The portion of total profit or loss that belongs to minority shareholders who own less than 50% of a subsidiary. Common terms: Profit attributable to non-controlling interests, Profit attributable to minority interests")

# %%
# Define the system prompt separately for better readability and maintenance
FINANCIAL_STATEMENT_PROMPT = """You are a Singapore financial reporting specialist who converts annual reports to XBRL format.
Your task is to extract and map financial data from input reports into standardized Statement of Profit or Loss fields.

IMPORTANT MAPPING GUIDELINES:
1. For each financial item, extract both Current Financial Year (CFY) and Previous Financial Year (PFY) values when available.
   - CFY values are required for mandatory fields
   - PFY values should be included when available, but can be omitted if not present

2. Pay close attention to financial terminology and map fields based on accounting meaning rather than exact names.
3. Map fields according to Singapore XBRL taxonomy and reporting standards.

4. Match input fields to the StatementOfProfitOrLoss model structure, handling common variations such as:
   - 'revenue' matches with: 'Revenue', 'Turnover', 'Sales', etc.
   - 'employee_benefits_expense' matches with: 'Employee Benefits Expense', 'Staff costs', 'Personnel expenses', etc.
   - 'depreciation_expense' matches with: 'Depreciation', 'Depreciation of Property, Plant and Equipment', etc.
   - 'amortisation_expense' matches with: 'Amortisation', 'Amortization', 'Amortisation of Intangible Assets', etc.
   - 'repairs_maintenance_expense' matches with: 'Repairs and Maintenance', 'Maintenance costs', etc.
   - 'sales_marketing_expense' matches with: 'Sales and Marketing', 'Marketing expenses', 'Advertising costs', etc.
   - 'other_expenses' matches with: 'Other Operating Expenses', 'General expenses', 'Administrative expenses', etc.
   - 'other_gains_losses' matches with: 'Foreign Exchange Gain/(Loss)', 'Other gains', 'Fair value changes', etc.
   - 'finance_costs_net' matches with: 'Finance Costs', 'Interest expense', 'Financial expenses', etc.
   - 'profit_loss_before_taxation' matches with: 'Profit Before Tax', 'Profit before income tax', etc.
   - 'income_tax_expense_benefit' matches with: 'Income Tax Expense', 'Tax expense', 'Taxation', etc.
   - 'total_profit_loss' matches with: 'Profit For The Year', 'Net profit', 'Total comprehensive income', etc.

5. The input data may present CFY/PFY values in different formats:
   - As separate fields: "Revenue 2024" and "Revenue 2023"
   - As nested objects: {"Revenue": {"CFY": 1000000, "PFY": 900000}}
   - In a tabular format where values are in different columns
   - Sometimes labeled as "Current Year" and "Previous Year"

6. Focus on extracting numerical values only - ignore metadata fields like company names, dates, or notes.

7. If needed information isn't explicitly given but can be calculated from other fields, perform the calculation.
   
8. Return all detected fields that correspond to the Statement of Profit or Loss structure with each value containing:
   - CFY: The current financial year value (required for mandatory fields)
   - PFY: The previous financial year value (if available)

9. The three required fields that must have at least CFY values are:
   - revenue
   - profit_loss_before_taxation
   - income_tax_expense_benefit
"""

# %%
dummy_data = {
    "revenue": 1000000.0,
    "other_income": 50000.0,
    "staff_costs": 350000.0,  # should map to employee_benefits_expense
    "depreciation": 75000.0,  # should map to depreciation_expense
    "amortization": 25000.0,  # should map to amortisation_expense
    "repairs_and_maintenance": 30000.0,  # should map to repairs_maintenance_expense
    "marketing_expenses": 120000.0,  # should map to sales_marketing_expense
    "general_expenses": 80000.0,  # should map to other_expenses
    "foreign_exchange_gain": 15000.0,  # should map to other_gains_losses
    "interest_expense": 40000.0,  # should map to finance_costs_net
    "share_of_results_from_associates": 35000.0,  # should map to share_of_profit_loss_associates
    "profit_before_tax": 380000.0,  # should map to profit_loss_before_taxation
    "tax_expense": 65000.0,  # should map to income_tax_expense_benefit
    "loss_from_discontinued_ops": 10000.0,  # should map to profit_loss_discontinued_operations
    "net_profit": 305000.0,  # should map to total_profit_loss
    "profit_attributable_to_shareholders": 290000.0,  # should map to profit_loss_attributable_to_owners
    "profit_attributable_to_minority_interests": 15000.0,  # should map to profit_loss_attributable_to_non_controlling
    
    # Some noise fields
    "company_name": "Test Company Ltd",
    "year": 2024,
    "current_ratio": 1.5
}

# %%
dummy_profit_loss_data = {
    "Revenue": {
        "CFY": 12500000,
        "PFY": 11250000
    },
    "Other Income": {
        "CFY": 350000,
        "PFY": 275000
    },
    "Employee Benefits Expense": {
        "CFY": -4750000,
        "PFY": -4250000
    },
    "Depreciation of Property, Plant and Equipment": {
        "CFY": -780000,
        "PFY": -720000
    },
    "Amortisation of Intangible Assets": {
        "CFY": -180000,
        "PFY": -165000
    },
    "Repairs and Maintenance": {
        "CFY": -320000,
        "PFY": -280000
    },
    "Sales and Marketing": {
        "CFY": -1450000,
        "PFY": -1350000
    },
    "Other Operating Expenses": {
        "CFY": -970000,
        "PFY": -850000
    },
    "Foreign Exchange Gain/(Loss)": {
        "CFY": 85000,
        "PFY": -120000
    },
    "Finance Costs": {
        "CFY": -325000,
        "PFY": -290000
    },
    "Share of Results of Associates": {
        "CFY": 620000,
        "PFY": 580000
    },
    "Profit Before Tax": {
        "CFY": 4780000,
        "PFY": 4080000
    },
    "Income Tax Expense": {
        "CFY": -860000,
        "PFY": -735000
    },
    "Profit From Continuing Operations": {
        "CFY": 3920000,
        "PFY": 3345000
    },
    "Loss From Discontinued Operations": {
        "CFY": -150000,
        "PFY": -275000
    },
    "Profit For The Year": {
        "CFY": 3770000,
        "PFY": 3070000
    },
    "Attributable to:": {
        "Owners of the Company": {
            "CFY": 3620000,
            "PFY": 2950000
        },
        "Non-controlling Interests": {
            "CFY": 150000,
            "PFY": 120000
        }
    },
    "Earnings Per Share (in cents)": {
        "Basic": {
            "CFY": 18.5,
            "PFY": 15.1
        },
        "Diluted": {
            "CFY": 18.2,
            "PFY": 14.8
        }
    },
    "Company Information": {
        "Name": "Singapore Ventures Ltd",
        "Financial Year": "2024",
        "Reporting Currency": "SGD"
    }
}

# %%
from pydantic_ai import Agent, ModelRetry
# import logfire
# logfire.configure()

model_name = 'google-gla:gemini-1.5-pro' if USE_GEMINI else 'openai:gpt-4o-mini'

# Define the agent
financial_statement_agent = Agent(
    model_name,
    result_type=StatementOfProfitOrLoss,
    system_prompt=FINANCIAL_STATEMENT_PROMPT
)

# %%
import json
# Convert the dummy data to a JSON string (optionally, you can use indent=4 for readability)
dummy_data_json = json.dumps(dummy_profit_loss_data, indent=4)

# Use an f-string to inject the dummy data into your prompt:
result = await financial_statement_agent.run(
    f'please map my data here: {dummy_data_json}'
)

# %%
print(result.data)
# Out:
# revenue=YearlyValue(CFY=12500000.0, PFY=11250000.0) other_income=YearlyValue(CFY=350000.0, PFY=275000.0) employee_benefits_expense=YearlyValue(CFY=-4750000.0, PFY=-4250000.0) depreciation_expense=YearlyValue(CFY=-780000.0, PFY=-720000.0) amortisation_expense=YearlyValue(CFY=-180000.0, PFY=-165000.0) repairs_maintenance_expense=YearlyValue(CFY=-320000.0, PFY=-280000.0) sales_marketing_expense=YearlyValue(CFY=-1450000.0, PFY=-1350000.0) other_expenses=YearlyValue(CFY=-970000.0, PFY=-850000.0) other_gains_losses=YearlyValue(CFY=85000.0, PFY=-120000.0) finance_costs_net=YearlyValue(CFY=-325000.0, PFY=-290000.0) share_of_profit_loss_associates=YearlyValue(CFY=620000.0, PFY=580000.0) profit_loss_before_taxation=YearlyValue(CFY=4780000.0, PFY=4080000.0) income_tax_expense_benefit=YearlyValue(CFY=-860000.0, PFY=-735000.0) profit_loss_discontinued_operations=YearlyValue(CFY=-150000.0, PFY=-275000.0) total_profit_loss=YearlyValue(CFY=3770000.0, PFY=3070000.0) profit_loss_attributable_to_owners=YearlyValue(CFY=3620000.0, PFY=2950000.0) profit_loss_attributable_to_non_controlling=YearlyValue(CFY=150000.0, PFY=120000.0)

# %%
from devtools import debug
debug(result)
# Out:
# C:\Users\almos\AppData\Local\Temp\ipykernel_11316\702232478.py:2 <module>
#     result: AgentRunResult(
#         data=StatementOfProfitOrLoss(
#             revenue=YearlyValue(
#                 CFY=12500000.0,
#                 PFY=11250000.0,
#             ),
#             other_income=YearlyValue(
#                 CFY=350000.0,
#                 PFY=275000.0,
#             ),
#             employee_benefits_expense=YearlyValue(
#                 CFY=-4750000.0,
#                 PFY=-4250000.0,
#             ),
#             depreciation_expense=YearlyValue(
#                 CFY=-780000.0,
#                 PFY=-720000.0,
#             ),
#             amortisation_expense=YearlyValue(
#                 CFY=-180000.0,
#                 PFY=-165000.0,
#             ),
#             repairs_maintenance_expense=YearlyValue(
#                 CFY=-320000.0,
#                 PFY=-280000.0,
#             ),
#             sales_marketing_expense=YearlyValue(
#                 CFY=-1450000.0,
#                 PFY=-1350000.0,
#             ),
#             other_expenses=YearlyValue(
#                 CFY=-970000.0,
#                 PFY=-850000.0,
#             ),
#             other_gains_losses=YearlyValue(
#                 CFY=85000.0,
#                 PFY=-120000.0,
#             ),
#             finance_costs_net=YearlyValue(
#                 CFY=-325000.0,
#                 PFY=-290000.0,
#             ),
#             share_of_profit_loss_associates=YearlyValue(
#                 CFY=620000.0,
#                 PFY=580000.0,
#             ),
#             profit_loss_before_taxation=YearlyValue(
#                 CFY=4780000.0,
#                 PFY=4080000.0,
#             ),
#             income_tax_expense_benefit=YearlyValue(
#                 CFY=-860000.0,
#                 PFY=-735000.0,
#             ),
#             profit_loss_discontinued_operations=YearlyValue(
#                 CFY=-150000.0,
#                 PFY=-275000.0,
#             ),
#             total_profit_loss=YearlyValue(
#                 CFY=3770000.0,
#                 PFY=3070000.0,
#             ),
#             profit_loss_attributable_to_owners=YearlyValue(
#                 CFY=3620000.0,
#                 PFY=2950000.0,
#             ),
#             profit_loss_attributable_to_non_controlling=YearlyValue(
#                 CFY=150000.0,
#                 PFY=120000.0,
#             ),
#         ),
#         _result_tool_name='final_result',
#         _state=GraphAgentState(
#             message_history=[
#                 ModelRequest(
#                     parts=[
#                         SystemPromptPart(
#                             content=(
#                                 'You are a Singapore financial reporting specialist who converts annual reports to XBR'
#                                 'L format.\n'
#                                 'Your task is to extract and map financial data from input reports into standardized S'
#                                 'tatement of Profit or Loss fields.\n'
#                                 '\n'
#                                 'IMPORTANT MAPPING GUIDELINES:\n'
#                                 '1. For each financial item, extract both Current Financial Year (CFY) and Previous Fi'
#                                 'nancial Year (PFY) values when available.\n'
#                                 '   - CFY values are required for mandatory fields\n'
#                                 '   - PFY values should be included when available, but can be omitted if not present\n'
#                                 '\n'
#                                 '2. Pay close attention to financial terminology and map fields based on accounting me'
#                                 'aning rather than exact names.\n'
#                                 '3. Map fields according to Singapore XBRL taxonomy and reporting standards.\n'
#                                 '\n'
#                                 '4. Match input fields to the StatementOfProfitOrLoss model structure, handling common'
#                                 ' variations such as:\n'
#                                 "   - 'revenue' matches with: 'Revenue', 'Turnover', 'Sales', etc.\n"
#                                 "   - 'employee_benefits_expense' matches with: 'Employee Benefits Expense', 'Staff co"
#                                 "sts', 'Personnel expenses', etc.\n"
#                                 "   - 'depreciation_expense' matches with: 'Depreciation', 'Depreciation of Property, "
#                                 "Plant and Equipment', etc.\n"
#                                 "   - 'amortisation_expense' matches with: 'Amortisation', 'Amortization', 'Amortisati"
#                                 "on of Intangible Assets', etc.\n"
#                                 "   - 'repairs_maintenance_expense' matches with: 'Repairs and Maintenance', 'Maintena"
#                                 "nce costs', etc.\n"
#                                 "   - 'sales_marketing_expense' matches with: 'Sales and Marketing', 'Marketing expens"
#                                 "es', 'Advertising costs', etc.\n"
#                                 "   - 'other_expenses' matches with: 'Other Operating Expenses', 'General expenses', '"
#                                 "Administrative expenses', etc.\n"
#                                 "   - 'other_gains_losses' matches with: 'Foreign Exchange Gain/(Loss)', 'Other gains'"
#                                 ", 'Fair value changes', etc.\n"
#                                 "   - 'finance_costs_net' matches with: 'Finance Costs', 'Interest expense', 'Financia"
#                                 "l expenses', etc.\n"
#                                 "   - 'profit_loss_before_taxation' matches with: 'Profit Before Tax', 'Profit before "
#                                 "income tax', etc.\n"
#                                 "   - 'income_tax_expense_benefit' matches with: 'Income Tax Expense', 'Tax expense', "
#                                 "'Taxation', etc.\n"
#                                 "   - 'total_profit_loss' matches with: 'Profit For The Year', 'Net profit', 'Total co"
#                                 "mprehensive income', etc.\n"
#                                 '\n'
#                                 '5. The input data may present CFY/PFY values in different formats:\n'
#                                 '   - As separate fields: "Revenue 2024" and "Revenue 2023"\n'
#                                 '   - As nested objects: {"Revenue": {"CFY": 1000000, "PFY": 900000}}\n'
#                                 '   - In a tabular format where values are in different columns\n'
#                                 '   - Sometimes labeled as "Current Year" and "Previous Year"\n'
#                                 '\n'
#                                 '6. Focus on extracting numerical values only - ignore metadata fields like company na'
#                                 'mes, dates, or notes.\n'
#                                 '\n'
#                                 "7. If needed information isn't explicitly given but can be calculated from other fiel"
#                                 'ds, perform the calculation.\n'
#                                 '   \n'
#                                 '8. Return all detected fields that correspond to the Statement of Profit or Loss stru'
#                                 'cture with each value containing:\n'
#                                 '   - CFY: The current financial year value (required for mandatory fields)\n'
#                                 '   - PFY: The previous financial year value (if available)\n'
#                                 '\n'
#                                 '9. The three required fields that must have at least CFY values are:\n'
#                                 '   - revenue\n'
#                                 '   - profit_loss_before_taxation\n'
#                                 '   - income_tax_expense_benefit\n'
#                             ),
#                             dynamic_ref=None,
#                             part_kind='system-prompt',
#                         ),
#                         UserPromptPart(
#                             content=(
#                                 'please map my data here: {\n'
#                                 '    "Revenue": {\n'
#                                 '        "CFY": 12500000,\n'
#                                 '        "PFY": 11250000\n'
#                                 '    },\n'
#                                 '    "Other Income": {\n'
#                                 '        "CFY": 350000,\n'
#                                 '        "PFY": 275000\n'
#                                 '    },\n'
#                                 '    "Employee Benefits Expense": {\n'
#                                 '        "CFY": -4750000,\n'
#                                 '        "PFY": -4250000\n'
#                                 '    },\n'
#                                 '    "Depreciation of Property, Plant and Equipment": {\n'
#                                 '        "CFY": -780000,\n'
#                                 '        "PFY": -720000\n'
#                                 '    },\n'
#                                 '    "Amortisation of Intangible Assets": {\n'
#                                 '        "CFY": -180000,\n'
#                                 '        "PFY": -165000\n'
#                                 '    },\n'
#                                 '    "Repairs and Maintenance": {\n'
#                                 '        "CFY": -320000,\n'
#                                 '        "PFY": -280000\n'
#                                 '    },\n'
#                                 '    "Sales and Marketing": {\n'
#                                 '        "CFY": -1450000,\n'
#                                 '        "PFY": -1350000\n'
#                                 '    },\n'
#                                 '    "Other Operating Expenses": {\n'
#                                 '        "CFY": -970000,\n'
#                                 '        "PFY": -850000\n'
#                                 '    },\n'
#                                 '    "Foreign Exchange Gain/(Loss)": {\n'
#                                 '        "CFY": 85000,\n'
#                                 '        "PFY": -120000\n'
#                                 '    },\n'
#                                 '    "Finance Costs": {\n'
#                                 '        "CFY": -325000,\n'
#                                 '        "PFY": -290000\n'
#                                 '    },\n'
#                                 '    "Share of Results of Associates": {\n'
#                                 '        "CFY": 620000,\n'
#                                 '        "PFY": 580000\n'
#                                 '    },\n'
#                                 '    "Profit Before Tax": {\n'
#                                 '        "CFY": 4780000,\n'
#                                 '        "PFY": 4080000\n'
#                                 '    },\n'
#                                 '    "Income Tax Expense": {\n'
#                                 '        "CFY": -860000,\n'
#                                 '        "PFY": -735000\n'
#                                 '    },\n'
#                                 '    "Profit From Continuing Operations": {\n'
#                                 '        "CFY": 3920000,\n'
#                                 '        "PFY": 3345000\n'
#                                 '    },\n'
#                                 '    "Loss From Discontinued Operations": {\n'
#                                 '        "CFY": -150000,\n'
#                                 '        "PFY": -275000\n'
#                                 '    },\n'
#                                 '    "Profit For The Year": {\n'
#                                 '        "CFY": 3770000,\n'
#                                 '        "PFY": 3070000\n'
#                                 '    },\n'
#                                 '    "Attributable to:": {\n'
#                                 '        "Owners of the Company": {\n'
#                                 '            "CFY": 3620000,\n'
#                                 '            "PFY": 2950000\n'
#                                 '        },\n'
#                                 '        "Non-controlling Interests": {\n'
#                                 '            "CFY": 150000,\n'
#                                 '            "PFY": 120000\n'
#                                 '        }\n'
#                                 '    },\n'
#                                 '    "Earnings Per Share (in cents)": {\n'
#                                 '        "Basic": {\n'
#                                 '            "CFY": 18.5,\n'
#                                 '            "PFY": 15.1\n'
#                                 '        },\n'
#                                 '        "Diluted": {\n'
#                                 '            "CFY": 18.2,\n'
#                                 '            "PFY": 14.8\n'
#                                 '        }\n'
#                                 '    },\n'
#                                 '    "Company Information": {\n'
#                                 '        "Name": "Singapore Ventures Ltd",\n'
#                                 '        "Financial Year": "2024",\n'
#                                 '        "Reporting Currency": "SGD"\n'
#                                 '    }\n'
#                                 '}'
#                             ),
#                             timestamp=datetime.datetime(2025, 3, 6, 15, 8, 29, 198298, tzinfo=datetime.timezone.utc),
#                             part_kind='user-prompt',
#                         ),
#                     ],
#                     kind='request',
#                 ),
#                 ModelResponse(
#                     parts=[
#                         ToolCallPart(
#                             tool_name='final_result',
#                             args={
#                                 'employee_benefits_expense': {
#                                     'CFY': -4750000,
#                                     'PFY': -4250000,
#                                 },
#                                 'income_tax_expense_benefit': {
#                                     'CFY': -860000,
#                                     'PFY': -735000,
#                                 },
#                                 'finance_costs_net': {
#                                     'CFY': -325000,
#                                     'PFY': -290000,
#                                 },
#                                 'profit_loss_before_taxation': {
#                                     'PFY': 4080000,
#                                     'CFY': 4780000,
#                                 },
#                                 'share_of_profit_loss_associates': {
#                                     'PFY': 580000,
#                                     'CFY': 620000,
#                                 },
#                                 'total_profit_loss': {
#                                     'CFY': 3770000,
#                                     'PFY': 3070000,
#                                 },
#                                 'sales_marketing_expense': {
#                                     'CFY': -1450000,
#                                     'PFY': -1350000,
#                                 },
#                                 'profit_loss_attributable_to_owners': {
#                                     'PFY': 2950000,
#                                     'CFY': 3620000,
#                                 },
#                                 'repairs_maintenance_expense': {
#                                     'CFY': -320000,
#                                     'PFY': -280000,
#                                 },
#                                 'other_income': {
#                                     'CFY': 350000,
#                                     'PFY': 275000,
#                                 },
#                                 'profit_loss_attributable_to_non_controlling': {
#                                     'PFY': 120000,
#                                     'CFY': 150000,
#                                 },
#                                 'amortisation_expense': {
#                                     'PFY': -165000,
#                                     'CFY': -180000,
#                                 },
#                                 'profit_loss_discontinued_operations': {
#                                     'CFY': -150000,
#                                     'PFY': -275000,
#                                 },
#                                 'other_gains_losses': {
#                                     'PFY': -120000,
#                                     'CFY': 85000,
#                                 },
#                                 'other_expenses': {
#                                     'CFY': -970000,
#                                     'PFY': -850000,
#                                 },
#                                 'revenue': {
#                                     'PFY': 11250000,
#                                     'CFY': 12500000,
#                                 },
#                                 'depreciation_expense': {
#                                     'CFY': -780000,
#                                     'PFY': -720000,
#                                 },
#                             },
#                             tool_call_id=None,
#                             part_kind='tool-call',
#                         ),
#                     ],
#                     model_name='gemini-1.5-pro-002',
#                     timestamp=datetime.datetime(2025, 3, 6, 15, 8, 37, 996231, tzinfo=datetime.timezone.utc),
#                     kind='response',
#                 ),
#                 ModelRequest(
#                     parts=[
#                         ToolReturnPart(
#                             tool_name='final_result',
#                             content='Final result processed.',
#                             tool_call_id=None,
#                             timestamp=datetime.datetime(2025, 3, 6, 15, 8, 37, 998222, tzinfo=datetime.timezone.utc),
#                             part_kind='tool-return',
#                         ),
#                     ],
#                     kind='request',
#                 ),
#             ],
#             usage=Usage(
#                 requests=1,
#                 request_tokens=2028,
#                 response_tokens=174,
#                 total_tokens=2202,
#                 details=None,
#             ),
#             retries=0,
#             run_step=1,
#         ),
#         _new_message_index=0,
#     ) (AgentRunResult)
# AgentRunResult(data=StatementOfProfitOrLoss(revenue=YearlyValue(CFY=12500000.0, PFY=11250000.0), other_income=YearlyValue(CFY=350000.0, PFY=275000.0), employee_benefits_expense=YearlyValue(CFY=-4750000.0, PFY=-4250000.0), depreciation_expense=YearlyValue(CFY=-780000.0, PFY=-720000.0), amortisation_expense=YearlyValue(CFY=-180000.0, PFY=-165000.0), repairs_maintenance_expense=YearlyValue(CFY=-320000.0, PFY=-280000.0), sales_marketing_expense=YearlyValue(CFY=-1450000.0, PFY=-1350000.0), other_expenses=YearlyValue(CFY=-970000.0, PFY=-850000.0), other_gains_losses=YearlyValue(CFY=85000.0, PFY=-120000.0), finance_costs_net=YearlyValue(CFY=-325000.0, PFY=-290000.0), share_of_profit_loss_associates=YearlyValue(CFY=620000.0, PFY=580000.0), profit_loss_before_taxation=YearlyValue(CFY=4780000.0, PFY=4080000.0), income_tax_expense_benefit=YearlyValue(CFY=-860000.0, PFY=-735000.0), profit_loss_discontinued_operations=YearlyValue(CFY=-150000.0, PFY=-275000.0), total_profit_loss=YearlyValue(CFY=3770000.0, PFY=3070000.0), profit_loss_attributable_to_owners=YearlyValue(CFY=3620000.0, PFY=2950000.0), profit_loss_attributable_to_non_controlling=YearlyValue(CFY=150000.0, PFY=120000.0)))
